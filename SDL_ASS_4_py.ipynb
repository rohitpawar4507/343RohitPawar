# %% [markdown]
# <a href="https://colab.research.google.com/github/rohitpawar4507/343RohitPawar/blob/master/SDL_ASS_4_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 4
#
# """Title: Write python code that loads any dataset from (www.data.gov.in), and does some basic data cleaning. Add component
# on data set. """
#
# # imports the library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the csv file

from google.colab import files   
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3cb3312b-e075-4cd8-a9e9-5866906a1e74" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3cb3312b-e075-4cd8-a9e9-5866906a1e74">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving flights.csv to flights.csv

# %%
df = pd.read_csv("Flights.csv")

# %%
df.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
# show column name in the dataset
print(df.columns)
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
# show the index in dataset
print(df.index)
# Out:
# RangeIndex(start=0, stop=144, step=1)

# %%
# statistical operation
print(df.describe())
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
# show count of dataset
print(df.count(axis=0))
# show shape of dataset
print(df.shape)
# Out:
# year          144
# month         144
# passengers    144
# dtype: int64
# (144, 3)

# %%
# datatypes
print(df.dtypes)
# Out:
# year           int64
# month         object
# passengers     int64
# dtype: object

# %%
# dataframe converted to numpy array
print(df.to_numpy())
# Out:
# [[1949 'January' 112]
#  [1949 'February' 118]
#  [1949 'March' 132]
#  [1949 'April' 129]
#  [1949 'May' 121]
#  [1949 'June' 135]
#  [1949 'July' 148]
#  [1949 'August' 148]
#  [1949 'September' 136]
#  [1949 'October' 119]
#  [1949 'November' 104]
#  [1949 'December' 118]
#  [1950 'January' 115]
#  [1950 'February' 126]
#  [1950 'March' 141]
#  [1950 'April' 135]
#  [1950 'May' 125]
#  [1950 'June' 149]
#  [1950 'July' 170]
#  [1950 'August' 170]
#  [1950 'September' 158]
#  [1950 'October' 133]
#  [1950 'November' 114]
#  [1950 'December' 140]
#  [1951 'January' 145]
#  [1951 'February' 150]
#  [1951 'March' 178]
#  [1951 'April' 163]
#  [1951 'May' 172]
#  [1951 'June' 178]
#  [1951 'July' 199]
#  [1951 'August' 199]
#  [1951 'September' 184]
#  [1951 'October' 162]
#  [1951 'November' 146]
#  [1951 'December' 166]
#  [1952 'January' 171]
#  [1952 'February' 180]
#  [1952 'March' 193]
#  [1952 'April' 181]
#  [1952 'May' 183]
#  [1952 'June' 218]
#  [1952 'July' 230]
#  [1952 'August' 242]
#  [1952 'September' 209]
#  [1952 'October' 191]
#  [1952 'November' 172]
#  [1952 'December' 194]
#  [1953 'January' 196]
#  [1953 'February' 196]
#  [1953 'March' 236]
#  [1953 'April' 235]
#  [1953 'May' 229]
#  [1953 'June' 243]
#  [1953 'July' 264]
#  [1953 'August' 272]
#  [1953 'September' 237]
#  [1953 'October' 211]
#  [1953 'November' 180]
#  [1953 'December' 201]
#  [1954 'January' 204]
#  [1954 'February' 188]
#  [1954 'March' 235]
#  [1954 'April' 227]
#  [1954 'May' 234]
#  [1954 'June' 264]
#  [1954 'July' 302]
#  [1954 'August' 293]
#  [1954 'September' 259]
#  [1954 'October' 229]
#  [1954 'November' 203]
#  [1954 'December' 229]
#  [1955 'January' 242]
#  [1955 'February' 233]
#  [1955 'March' 267]
#  [1955 'April' 269]
#  [1955 'May' 270]
#  [1955 'June' 315]
#  [1955 'July' 364]
#  [1955 'August' 347]
#  [1955 'September' 312]
#  [1955 'October' 274]
#  [1955 'November' 237]
#  [1955 'December' 278]
#  [1956 'January' 284]
#  [1956 'February' 277]
#  [1956 'March' 317]
#  [1956 'April' 313]
#  [1956 'May' 318]
#  [1956 'June' 374]
#  [1956 'July' 413]
#  [1956 'August' 405]
#  [1956 'September' 355]
#  [1956 'October' 306]
#  [1956 'November' 271]
#  [1956 'December' 306]
#  [1957 'January' 315]
#  [1957 'February' 301]
#  [1957 'March' 356]
#  [1957 'April' 348]
#  [1957 'May' 355]
#  [1957 'June' 422]
#  [1957 'July' 465]
#  [1957 'August' 467]
#  [1957 'September' 404]
#  [1957 'October' 347]
#  [1957 'November' 305]
#  [1957 'December' 336]
#  [1958 'January' 340]
#  [1958 'February' 318]
#  [1958 'March' 362]
#  [1958 'April' 348]
#  [1958 'May' 363]
#  [1958 'June' 435]
#  [1958 'July' 491]
#  [1958 'August' 505]
#  [1958 'September' 404]
#  [1958 'October' 359]
#  [1958 'November' 310]
#  [1958 'December' 337]
#  [1959 'January' 360]
#  [1959 'February' 342]
#  [1959 'March' 406]
#  [1959 'April' 396]
#  [1959 'May' 420]
#  [1959 'June' 472]
#  [1959 'July' 548]
#  [1959 'August' 559]
#  [1959 'September' 463]
#  [1959 'October' 407]
#  [1959 'November' 362]
#  [1959 'December' 405]
#  [1960 'January' 417]
#  [1960 'February' 391]
#  [1960 'March' 419]
#  [1960 'April' 461]
#  [1960 'May' 472]
#  [1960 'June' 535]
#  [1960 'July' 622]
#  [1960 'August' 606]
#  [1960 'September' 508]
#  [1960 'October' 461]
#  [1960 'November' 390]
#  [1960 'December' 432]]

# %%
# Transpose of matrix
print(df.T)
# Out:
#                 0         1      2    ...      141       142       143
# year           1949      1949   1949  ...     1960      1960      1960
# month       January  February  March  ...  October  November  December
# passengers      112       118    132  ...      461       390       432
#
# [3 rows x 144 columns]

# %%
# sorting data in reverse order axis =0 = row
print(df.sort_index(axis=0, ascending=False))
# Out:
#      year      month  passengers
# 143  1960   December         432
# 142  1960   November         390
# 141  1960    October         461
# 140  1960  September         508
# 139  1960     August         606
# ..    ...        ...         ...
# 4    1949        May         121
# 3    1949      April         129
# 2    1949      March         132
# 1    1949   February         118
# 0    1949    January         112
#
# [144 rows x 3 columns]

# %%
# sorting data in reverse order axis =1 = column
print(df.sort_index(axis=1, ascending=False))
# Out:
#      year  passengers      month
# 0    1949         112    January
# 1    1949         118   February
# 2    1949         132      March
# 3    1949         129      April
# 4    1949         121        May
# ..    ...         ...        ...
# 139  1960         606     August
# 140  1960         508  September
# 141  1960         461    October
# 142  1960         390   November
# 143  1960         432   December
#
# [144 rows x 3 columns]

# %%
# find info of all dataset
print(df.info)
# Out:
# <bound method DataFrame.info of      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]>

# %%
# changing / Set the columns name
df.columns = list(["sr_no","Experience","Salary"])
print(df.head())
# Out:
#    sr_no Experience  Salary
# 0   1949    January     112
# 1   1949   February     118
# 2   1949      March     132
# 3   1949      April     129
# 4   1949        May     121

# %%
# drop some columns or row value (axis =0 -> row, axis =1 ->columns)

print(df.drop(0,axis=0))
# Out:
#      sr_no Experience  Salary
# 1     1949   February     118
# 2     1949      March     132
# 3     1949      April     129
# 4     1949        May     121
# 5     1949       June     135
# ..     ...        ...     ...
# 139   1960     August     606
# 140   1960  September     508
# 141   1960    October     461
# 142   1960   November     390
# 143   1960   December     432
#
# [143 rows x 3 columns]

# %%
# print some specific value
print(df.loc[[1,2],['Experience','Salary']])
# Out:
#   Experience  Salary
# 1   February     118
# 2      March     132

# %%
# slicing
print(df.loc[20:,['Experience','Salary']])
# Out:
#     Experience  Salary
# 20   September     158
# 21     October     133
# 22    November     114
# 23    December     140
# 24     January     145
# ..         ...     ...
# 139     August     606
# 140  September     508
# 141    October     461
# 142   November     390
# 143   December     432
#
# [124 rows x 2 columns]

# %%
# modified value to NONE
df['Salary'] = None
print(df['Salary'])
print(df['Salary'].isnull())
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 139    None
# 140    None
# 141    None
# 142    None
# 143    None
# Name: Salary, Length: 144, dtype: object
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 139    True
# 140    True
# 141    True
# 142    True
# 143    True
# Name: Salary, Length: 144, dtype: bool

# %%
# checking NA value
print(df.isna())
# Out:
#      sr_no  Experience  Salary
# 0    False       False    True
# 1    False       False    True
# 2    False       False    True
# 3    False       False    True
# 4    False       False    True
# ..     ...         ...     ...
# 139  False       False    True
# 140  False       False    True
# 141  False       False    True
# 142  False       False    True
# 143  False       False    True
#
# [144 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a = sns.load_dataset("flights")
sns.relplot(x="passengers",y="month",hue="year",data=a)

# %%
# Bar graph 
sns.catplot(x="month",y="passengers",data=a,hue="year" ,kind='bar')

# %%
# Line Plot 
b = sns.load_dataset("flights")
sns.relplot(x="passengers",y="month",data=b,kind="line")

# %%
# Ploting categorical data with seaborn
# violin catplot
sns.catplot(x="month",y="passengers",kind="violin",data=b)

# %%
sns.catplot(x="month",y="passengers",kind="boxen",data=b)

# %%
# Univariate Distribution
from scipy import stats
c=np.random.normal(loc=5, size=100,scale=2)
plt.title=("Univariate Distribution")
sns.displot(c)

# %%
sns.set(style="dark")
a = sns.load_dataset("flights")
b = sns.PairGrid(a)
b.map(plt.scatter)

# %%
# plot box plot
sns.set(style="white",color_codes=True)
a=sns.load_dataset('flights')
sns.boxplot(x='month',y='passengers',data=a)
